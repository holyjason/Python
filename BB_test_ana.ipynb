# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pandas.plotting import andrews_curves

BBT = pd.read_excel("C:\\Test\\py\\PRIME_DU_a83513353973927a_201907051339500.xlsx","PRIME_DU_a83513353973927a_20190",
                    na_values={'Value':['Not Test','NaN'],
                               'LowerLimit':['Not Test','NaN',' '],
                               'UpperLimit':['Not Test','NaN',' '],
                               'Duration':['0','NaN']
                               })
# TODO Calc the test time
color = {'boxes': 'DarkGreen', 'whiskers': 'DarkOrange', 'medians': 'DarkBlue', 'caps': 'Gray'}
BBT['Duration'].plot.box(color=color, sym='r+')
plt.figure()

"""
# TODO Sort the index
SortUSBT = BBT.sort_values(['USB1ReadSpeed'], ascending=False)

# TODO Plot the Hbar Chart 
SortUSBT['USB1ReadSpeed'].head(10).plot(kind="barh")
plt.figure()

# TODO Plot the Hist Chart 
BBT['USB1WriteSpeed'].head(200).plot(kind='hist')
plt.figure()


# TODO Calc the test time
BBT['TestTime'] = BBT['EndDateTime'] - BBT['StartDateTime']
BBT['TestTime'].plot()
plt.figure()
color = {'boxes': 'DarkGreen', 'whiskers': 'DarkOrange', 'medians': 'DarkBlue', 'caps': 'Gray'}
BBT['TestTime'].plot.box(color=color, sym='r+')
plt.figure()

# TODO Box Plot ALL USB Write Speed
Bdata = BBT[['USB1WriteSpeed','USB2WriteSpeed','USB3WriteSpeed','USB4WriteSpeed']]
color = {'boxes': 'DarkGreen', 'whiskers': 'DarkOrange', 'medians': 'DarkBlue', 'caps': 'Gray'}
Bdata.plot.box(color=color, sym='r+')
plt.figure()

# TODO ALL USB Write Speed
Bdata.head(10).plot.bar(stacked=False)
plt.figure()

# TODO Box Plot ALL USB Read Speed
Adata = BBT[['USB1ReadSpeed','USB2ReadSpeed','USB3ReadSpeed','USB4ReadSpeed']]
color = {'boxes': 'DarkGreen', 'whiskers': 'DarkOrange', 'medians': 'DarkBlue', 'caps': 'Gray'}
Adata.plot.box(color=color, sym='r+')
plt.figure()

# TODO ALL USB Read Speed
Adata.head(10).plot.bar(stacked=False)
plt.figure()


#  USB Port1 Write Speed vs Read Speed 
USB1WriteData = BBT[['USB1WriteSpeed','USB1ReadSpeed']]
USB1WriteData.head(10).plot.bar(stacked=True)
plt.figure()


plt.show()
"""

# TODO Stastics
BBT.describe()
# Out:
#               TSRID  PartNumber  ErrorCode  Duration  ProductionTest  \
# count  1.400000e+01         0.0       14.0      14.0            14.0
# mean   2.019071e+14         NaN        0.0      37.0             1.0
# std    0.000000e+00         NaN        0.0       0.0             0.0
# min    2.019071e+14         NaN        0.0      37.0             1.0
# 25%    2.019071e+14         NaN        0.0      37.0             1.0
# 50%    2.019071e+14         NaN        0.0      37.0             1.0
# 75%    2.019071e+14         NaN        0.0      37.0             1.0
# max    2.019071e+14         NaN        0.0      37.0             1.0
#
#            Value  LowerLimit  UpperLimit  PegaCode
# count  12.000000   12.000000         8.0       0.0
# mean    3.299583    2.916667         5.5       NaN
# std     2.541659    2.338738         0.0       NaN
# min    -0.180000   -0.250000         5.5       NaN
# 25%    -0.085000   -0.250000         5.5       NaN
# 50%     4.928500    4.500000         5.5       NaN
# 75%     5.080250    4.500000         5.5       NaN
# max     5.101000    4.500000         5.5       NaN
